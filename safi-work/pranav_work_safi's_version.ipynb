# %% [markdown]
# ## Project Setup

# %%
import os
raw_dataset_path = './Datasets/raw_data/'
# Out:
# ['1890', '1830', '1800', '1720', '.DS_Store', '1780', '1710', '1750', '1760', '1840', '1870', '1860', '1850', '1770', '1740', '1700', '1730', '1790', '1810', '1880', '1820']

# %% [markdown]
# ## Data Preprocessing

# %%
# create new directory to store cleaned texts
directory='./Datasets/cleaned_data'
if not os.path.exists(directory):
  os.makedirs('./Datasets/cleaned_data')

# %%
import re 

def clean_text(text):
  # remove everything before start
  start_match = re.search(r'\*\*\* START OF.*?\*\*\*', text, re.IGNORECASE | re.DOTALL)
  if start_match:
    text = text[start_match.end():]

  # remove everything after end
  end_match = re.search(r'\*\*\* END OF.*?\*\*\*', text, re.IGNORECASE | re.DOTALL)
  if end_match:
    text = text[:end_match.start()]

  # remove years 1000's
  text = re.sub(r'\b1[0-9]{3}\b', '', text)

  # remove whitespace
  text = re.sub(r'\s+', ' ', text)

  return text.strip()

# %%
years = [1700, 1710, 1720, 1730, 1740, 1750, 1760, 1770, 1780, 1790]

# %%
import string

def preprocess_text(dataset_path, year):
  print(f"preprocess text")
  print(f"directory year: {year}")
  decade_path = dataset_path + str(year) + "/"
  cleaned_data_path = f'./Datasets/cleaned_data/{year}/'
  if not os.path.exists(cleaned_data_path):
    os.makedirs(cleaned_data_path)
  # process and clean each text file
  text_list = os.listdir(decade_path)
  for file in text_list:
    if file.endswith('.txt'):
      print(f"file name: {file}")

      # read file
      with open(decade_path + file, 'r', encoding='utf-8') as f:
        raw_text = f.read()

      cleaned_text = clean_text(raw_text)

      # save file
      out_file = cleaned_data_path + file
      with open(out_file, 'w', encoding='utf-8') as f:
        f.write(cleaned_text)
        print(f"cleaned text and save to -> {out_file}")
        print()

# %% [markdown]
# ### 1700's Texts

# %%
years = [1700, 1710, 1720, 1730, 1740, 1750, 1760, 1770, 1780, 1790]
# test_year = years[0]
# preprocess_text(raw_dataset_path, test_year)
for year in years:
  preprocess_text(raw_dataset_path, year)
# Out:
# preprocess text
# directory year: 1700
# file name: 1700_5.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1700/1700_5.txt
#
# file name: 1700_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1700/1700_4.txt
#
# file name: 1700_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1700/1700_1.txt
#
# file name: 1700_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1700/1700_3.txt
#
# file name: 1700_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1700/1700_2.txt
#
# preprocess text
# directory year: 1710
# file name: 1710_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1710/1710_4.txt
#
# file name: 1710_5.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1710/1710_5.txt
#
# file name: 1710_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1710/1710_2.txt
#
# file name: 1710_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1710/1710_3.txt
#
# file name: 1710_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1710/1710_1.txt
#
# preprocess text
# directory year: 1720
# file name: 1720_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1720/1720_3.txt
#
# file name: 1720_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1720/1720_2.txt
#
# file name: 1720_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1720/1720_1.txt
#
# file name: 1720_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1720/1720_4.txt
#
# preprocess text
# directory year: 1730
# file name: 1730_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1730/1730_1.txt
#
# file name: 1730_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1730/1730_2.txt
#
# file name: 1730_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1730/1730_3.txt
#
# file name: 1730_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1730/1730_4.txt
#
# preprocess text
# directory year: 1740
# file name: 1740_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1740/1740_1.txt
#
# file name: 1740_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1740/1740_2.txt
#
# file name: 1740_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1740/1740_3.txt
#
# file name: 1740_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1740/1740_4.txt
#
# file name: 1740_5.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1740/1740_5.txt
#
# preprocess text
# directory year: 1750
# file name: 1750_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1750/1750_3.txt
#
# file name: 1750_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1750/1750_2.txt
#
# file name: 1750_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1750/1750_1.txt
#
# file name: 1750_5.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1750/1750_5.txt
#
# file name: 1750_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1750/1750_4.txt
#
# preprocess text
# directory year: 1760
# file name: 1760_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1760/1760_4.txt
#
# file name: 1760_5.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1760/1760_5.txt
#
# file name: 1760_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1760/1760_2.txt
#
# file name: 1760_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1760/1760_3.txt
#
# file name: 1760_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1760/1760_1.txt
#
# preprocess text
# directory year: 1770
# file name: 1770_5.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1770/1770_5.txt
#
# file name: 1770_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1770/1770_4.txt
#
# file name: 1770_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1770/1770_1.txt
#
# file name: 1770_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1770/1770_3.txt
#
# file name: 1770_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1770/1770_2.txt
#
# preprocess text
# directory year: 1780
# file name: 1780_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1780/1780_1.txt
#
# file name: 1780_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1780/1780_2.txt
#
# file name: 1780_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1780/1780_3.txt
#
# file name: 1780_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1780/1780_4.txt
#
# file name: 1780_5.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1780/1780_5.txt
#
# preprocess text
# directory year: 1790
# file name: 1790_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1790/1790_3.txt
#
# file name: 1790_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1790/1790_2.txt
#
# file name: 1790_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1790/1790_1.txt
#
# file name: 1790_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1790/1790_4.txt

# %% [markdown]
# ### 1800's Texts

# %%
years = [1800, 1810, 1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890]
for year in years:
  preprocess_text(raw_dataset_path, year)
# Out:
# preprocess text
# directory year: 1800
# file name: 1800_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1800/1800_2.txt
#
# file name: 1800_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1800/1800_3.txt
#
# file name: 1800_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1800/1800_1.txt
#
# file name: 1800_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1800/1800_4.txt
#
# file name: 1800_5.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1800/1800_5.txt
#
# file name: 1800_6.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1800/1800_6.txt
#
# preprocess text
# directory year: 1810
# file name: 1810_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1810/1810_1.txt
#
# file name: 1810_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1810/1810_3.txt
#
# file name: 1810_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1810/1810_2.txt
#
# file name: 1810_5.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1810/1810_5.txt
#
# file name: 1810_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1810/1810_4.txt
#
# preprocess text
# directory year: 1820
# file name: 1820_6.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1820/1820_6.txt
#
# file name: 1820_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1820/1820_4.txt
#
# file name: 1820_5.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1820/1820_5.txt
#
# file name: 1820_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1820/1820_1.txt
#
# file name: 1820_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1820/1820_2.txt
#
# file name: 1820_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1820/1820_3.txt
#
# preprocess text
# directory year: 1830
# file name: 1830_5.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1830/1830_5.txt
#
# file name: 1830_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1830/1830_4.txt
#
# file name: 1830_6.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1830/1830_6.txt
#
# file name: 1830_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1830/1830_3.txt
#
# file name: 1830_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1830/1830_2.txt
#
# file name: 1830_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1830/1830_1.txt
#
# preprocess text
# directory year: 1840
# file name: 1840_5.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1840/1840_5.txt
#
# file name: 1840_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1840/1840_4.txt
#
# file name: 1840_6.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1840/1840_6.txt
#
# file name: 1840_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1840/1840_3.txt
#
# file name: 1840_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1840/1840_2.txt
#
# file name: 1840_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1840/1840_1.txt
#
# preprocess text
# directory year: 1850
# file name: 1850_6.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1850/1850_6.txt
#
# file name: 1850_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1850/1850_4.txt
#
# file name: 1850_5.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1850/1850_5.txt
#
# file name: 1850_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1850/1850_1.txt
#
# file name: 1850_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1850/1850_2.txt
#
# file name: 1850_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1850/1850_3.txt
#
# preprocess text
# directory year: 1860
# file name: 1860_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1860/1860_1.txt
#
# file name: 1860_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1860/1860_3.txt
#
# file name: 1860_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1860/1860_2.txt
#
# file name: 1860_5.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1860/1860_5.txt
#
# file name: 1860_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1860/1860_4.txt
#
# preprocess text
# directory year: 1870
# file name: 1870_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1870/1870_2.txt
#
# file name: 1870_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1870/1870_3.txt
#
# file name: 1870_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1870/1870_1.txt
#
# file name: 1870_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1870/1870_4.txt
#
# file name: 1870_5.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1870/1870_5.txt
#
# preprocess text
# directory year: 1880
# file name: 1880_5.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1880/1880_5.txt
#
# file name: 1880_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1880/1880_4.txt
#
# file name: 1880_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1880/1880_3.txt
#
# file name: 1880_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1880/1880_2.txt
#
# file name: 1880_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1880/1880_1.txt
#
# preprocess text
# directory year: 1890
# file name: 1890_4.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1890/1890_4.txt
#
# file name: 1890_5.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1890/1890_5.txt
#
# file name: 1890_1.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1890/1890_1.txt
#
# file name: 1890_2.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1890/1890_2.txt
#
# file name: 1890_3.txt
# cleaned text and save to -> ./Datasets/cleaned_data/1890/1890_3.txt
